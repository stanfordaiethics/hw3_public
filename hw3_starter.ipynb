# %%
"""
Starter code for CS 281 HW3.
"""
import math

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Don't modify these; especially the seed!
np.random.seed(42)
n = 10000
d = 10

X = np.array([np.random.binomial(n=1, p=p0, size=n) for p0 in np.random.random(10)]).T

# %% [markdown]
# # 1. The Laplace mechanism

# %%
def laplace_mechanism(X, sensitivity, epsilon, seed):
    """
    Computes M(X) = f(X) + W, where W is sampled
    from a Laplace distribution

    Hint: You can use the np.random.laplace function

    This should work for both univariate and multivariate X
    """
    np.random.seed(seed)
    raise NotImplementedError("TODO")

# %% [markdown]
# ## 1.2.b. Univariate

# %%
l1_sens_uni = # TODO: fill in sensitivity

# %%
j = 0 # We are looking only at diabetes

for epsilon in [0.01, 0.1, 1]:
    # TODO: calculate the laplace mechanism over 1000 different seeds
    #       for X[:, j] and using l1_sens_uni sensitivity

# %%
# TODO: make 3 plots (one per epsilon). Only visualize
#       the x-axis between [0.3, 0.5] and set the number of bins to be 30
#       ONE way you could do this is
#                g = sns.FacetGrid(df, col='epsilon')
#                g.map(sns.histplot, 'mean', bins=30)
#       where df is collected information above
#       Finally, don't forget to plot the true condition mean as a vertical red line.

# %% [markdown]
# ## 1.3.b. Multivariate

# %%
l1_sens_multi = # TODO: fill in sensitivity

# %%
for epsilon in [0.01, 0.1, 1]:
    # TODO: calculate the laplace mechanism over 1000 different seeds
    #       for all X and using l1_sens_multi sensitivity

# %%
# TODO: Plot 5 x 3 distributions.
#       For each of features j = 0, ... 4, make 3 plots (one per epsilon). Only visualize
#       the x-axis between [-.5, 1.5] and set the number of bins to be 30
#       Don't forget to plot the true condition mean as a vertical red line.

# %% [markdown]
# # 2. The Gaussian mechanism

# %%
def gaussian_mechanism(X, sensitivity, epsilon, delta, seed):
    """
    Computes M(X) = f(X) + W, where W is sampled
    from a Gaussian distribution
    """
    np.random.seed(seed)
    raise NotImplementedError("TODO")

# %% [markdown]
# ## 2.1.b. Multivariate

# %%
l2_sens_multi = # TODO

# %%
delta = 0.01

for epsilon in [0.01, 0.1, 1]:
    # TODO: calculate the Gaussian mechanism over 1000 different seeds
    #       for all X and using l2_sens_multi sensitivity

# %%
# TODO: make 3 plots (one per epsilon). Only visualize
#       the x-axis between [-.5,1.5] and set the number of bins to be 30
#       ONE way you could do this is
#                g = sns.FacetGrid(df, col='epsilon')
#                g.map(sns.histplot, 'mean', bins=30)
#       where df is collected information above
#       Finally, don't forget to plot the true condition mean as a vertical red line.

# %% [markdown]
# ## 2.2. Comparing sensitivity

# %%
delta = 0.01
epsilon = 0.1

for sens in [l1_sens_multi, l2_sens_multi]:
    # TODO: calculate the Laplace and Gaussian mechanisms, each over 1000 different seeds
    #       for all X and using the corresponding sensitivity

# %%
# TODO: make 4 plots for each sensitvity and for each mechanism. Only visualize
#       the x-axis between [0, 0.6] and set the number of bins to be 30
